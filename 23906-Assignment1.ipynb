# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Name': ['Alice','BOB','Charlie'],
    'Age' : [22,25,20],
    'City': ['London', 'Paris', 'New York']
}

df1 = pd.DataFrame(data)
df1
# Out:
#       Name  Age      City
# 0    Alice   22    London
# 1      BOB   25     Paris
# 2  Charlie   20  New York

# %%
from sklearn import datasets as ds

data_dict = ds.load_diabetes(as_frame=True)
# data_dict
df = data_dict['data']

# dir(ds)

# %%
names = ['Aarti', "Aarti", "Abhay", "Abhaya", "Aditi", "Aditya", "Advika", "Agni", "Aishwarya", "Akash", "Akhila", "Akshay", "Alia", "Alok", "Amaan", "Amara", "Amaravati", "Ambika", "Amit", "Amrita","Advika", "Agni", "Aishwarya", "Akash", "Akhila", "Akshay", "Alia", "Alok", "Amaan", "Amara", "Amaravati", "Ambika", "Amit", "Amrita", "Anand", "Ananya", "Anika", "Anil", "Anjali", "Ankita", "Ansh", "Anuja", "Anupam", "Anushka", "Archana", "Arjun", "Arpita", "Arya", "Asha", "Ashish", "Asmita", "Avani", "Ayush", "Bhanu", "Bhavana", "Bhuvan", "Chaitanya", "Charan", "Chitra", "Deepak", "Devika", "Dhruv", "Divya", "Ekta", "Esha", "Gautam", "Gayatri", "Geeta", "Gopal", "Gauri", "Hema", "Ishaan", "Indira", "Ishita", "Jai", "Janaki", "Jaya", "Jyoti", "Kabir", "Kalyani", "Karthik", "Kavita", "Kritika", "Lakshmi", "Lokesh", "Madhavi", "Mahesh", "Malini", "Manish", "Meera", "Mohan", "Monika", "Mukesh", "Naina", "Namita", "Naveen", "Neelam", "Neha", "Niharika", "Nikhil", "Nisha", "Nitin", "Pallavi", "Pankaj", "Parvati", "Prakash", "Prerna", "Priya", "Rahul", "Rajesh", "Rani", "Rishi", "Ritu", "Rohan", "Roopa", "Rupesh", "Sachin", "Sagar", "Sakshi", "Samir", "Sangeeta", "Sanjay", "Santosh", "Sarika", "Shalini", "Shashi", "Sheetal", "Shivani", "Siddharth", "Simran", "Sonia", "Sujata", "Sumit", "Sunil", "Suresh", "Swati", "Tanvi", "Tara", "Tejas", "Tina", "Uday", "Usha", "Venu", "Vicky", "Vidya", "Vikram", "Vishal", "Yash","Aarav", "Aarti", "Abhay", "Abhaya", "Aditi", "Aditya", "Advika", "Agni", "Aishwarya", "Akash", "Akhila", "Akshay", "Alia", "Alok", "Amaan", "Amara", "Amaravati", "Ambika", "Amit", "Amrita", "Anand", "Ananya", "Anika", "Anil", "Anjali", "Ankita", "Ansh", "Anuja", "Anupam", "Anushka", "Archana", "Arjun", "Arpita", "Arya", "Asha", "Ashish", "Asmita", "Avani", "Ayush", "Bhanu", "Bhavana", "Bhuvan", "Chaitanya", "Charan", "Chitra", "Deepak", "Devika", "Dhruv", "Divya", "Ekta", "Esha", "Gautam", "Gayatri", "Geeta", "Gopal", "Gauri", "Hema", "Ishaan", "Indira", "Ishita", "
# 0     Aarti  1234 5678 9012 3456  0.038076  0.050680  0.061696  0.021872
# 1     Aarti  1234 5678 9012 3457 -0.001882 -0.044642 -0.051474 -0.026328
# 2     Abhay  1234 5678 9012 3458  0.085299  0.050680  0.044451 -0.005670
# 3    Abhaya  1234 5678 9012 3459 -0.089063 -0.044642 -0.011595 -0.036656
# 4     Aditi  1234 5678 9012 3460  0.005383 -0.044642 -0.036385  0.021872
# ..      ...                  ...       ...       ...       ...       ...
# 437  Ananya  6543 2109 8765 4321  0.041708  0.050680  0.019662  0.059744
# 438   Anika  6543 2109 8765 4322 -0.005515  0.050680 -0.015906 -0.067642
# 439    Anil  6543 2109 8765 4323  0.041708  0.050680 -0.015906  0.017293
# 440  Anjali  6543 2109 8765 4324 -0.045472 -0.044642  0.039062  0.001215
# 441  Ankita  6543 2109 8765 4325 -0.045472 -0.044642 -0.073030 -0.081413
#
#            s1        s2        s3        s4        s5        s6
# ...

# %% [markdown]
# ### Diabetes-Logistic Regression

# %%
def diagnostic_plots(df,variable,target):
    
    # figure size
    plt.figure(figsize=(20,7))

    #Histogram
    plt.subplot(1,4,1)
    sns.histplot(df[variable], kde=True, color = 'r')
    plt.title('Histogram')

    # Scatter
    plt.subplot(1,4,2)
    plt.scatter(df[variable], df[target], color = 'g')
    plt.title("Scatterplot")

    # Barplot
    plt.subplot(1,4,3)
    sns.barplot(x = target, y = variable, data = df)
    plt.title('Barplot')

    plt.show()

# %%
diagnostic_plots(df,'bmi','age')

# %% [markdown]
# ### Line plot

# %% [markdown]
# * Line graphs are used to track changes over short and long periods of time.
# * When smaller changes exist, line graphs are better to use than bar graphs.
# * Line graphs can also be used to compare changes over the same period of time for more than one group

# %%
df1 = pd.read_csv("./diabetes.csv")
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.lineplot(data = df1, x = "Age", y = "Glucose",hue="Outcome")
# 1 = Yes (diabetes is there)
# 0 = No
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %% [markdown]
# * The people who have diabetes have higher glucose level as compared to those who don't have.

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
#  * Use a scatter plot to determine whether or not two variables have a relationship or correlation.
#  * Plotting a scattergram with your data points can help you to determine whether there is a potential relationship between them

# %%
sns.scatterplot(data = df1, x = "Glucose", y = "BMI", hue = "Outcome")
# Out:
# <Axes: xlabel='Glucose', ylabel='BMI'>

# %% [markdown]
# * We can see that people who are not having diabetes have a lower Glucose and BMI compared to those who have diabetes.

# %% [markdown]
# ### Stacked Bar Plot

# %%
df2 = df1.drop(['Pregnancies', 'SkinThickness','DiabetesPedigreeFunction','Insulin',"Outcome"], axis=1)
for i in range(21,768):
    df2.drop(index=[i], inplace=True)
df2
# Out:
#     Glucose  BloodPressure   BMI  Age
# 0       148             72  33.6   50
# 1        85             66  26.6   31
# 2       183             64  23.3   32
# 3        89             66  28.1   21
# 4       137             40  43.1   33
# 5       116             74  25.6   30
# 6        78             50  31.0   26
# 7       115              0  35.3   29
# 8       197             70  30.5   53
# 9       125             96   0.0   54
# 10      110             92  37.6   30
# 11      168             74  38.0   34
# 12      139             80  27.1   57
# 13      189             60  30.1   59
# 14      166             72  25.8   51
# 15      100              0  30.0   32
# 16      118             84  45.8   31
# 17      107             74  29.6   31
# 18      103             30  43.3   33
# 19      115             70  34.6   32
# 20      126             88  39.3   27

# %%
df2.plot(kind='bar', stacked=True, color=['red', 'skyblue','green','blue'])
# Out:
# <Axes: >

# %%
# creating our own data 
x = ['A','B','C','D','E']
y1 = [10,20,30,10,30] 
y2 = [5,15,20,25,10]

# bar plots (Stacked)
plt.bar(x, y1, color='g')
plt.bar(x, y2, color='b')
plt.legend(["Y1","Y2"])
plt.show()

# %%
x = ['A','B','C','D']
y1 = np.array([10,20,10,30]) 
y2 = np.array([20,25,15,25])
y3 = np.array([12,15,19,6])
y4 = np.array([10,29,13,19])

plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.bar(x, y3, bottom=y1+y2 ,color='g')
plt.bar(x, y4, bottom=y1+y2+y3 ,color='y')
plt.show()

# %% [markdown]
# ### Box Plot

# %% [markdown]
# A box plot consist of 5 things.
#
# Minimum
# First Quartile or 25%
# Median (Second Quartile) or 50%
# Third Quartile or 75%
# Maximum

# %%
df2 = pd.read_csv('./tips.csv')     # data set from (https://www.geeksforgeeks.org/box-plot-visualization-with-pandas-and-seaborn/)
df2.boxplot(by = 'day', column=['tip'], grid =False)
# Out:
# <Axes: title={'center': 'tip'}, xlabel='day'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = df2)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# * Bottom black horizontal line of blue box plot is minimum value
# * First black horizontal line of rectangle shape of blue box plot is First quartile or 25%
# * Second black horizontal line of rectangle shape of blue box plot is Second quartile or 50% or median.
# * Third black horizontal line of rectangle shape of blue box plot is third quartile or 75%
# * Top black horizontal line of rectangle shape of blue box plot is maximum value.
# * Small diamond shape of blue box plot is outlier data or erroneous data.

# %%
sns.boxplot(x = 'sex', y = 'bp', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='bp'>

# %% [markdown]
# * The Blood Pressure of the sex (-0.04) is right skewed which means most of the data lies on the other(left) side of the median.

# %%
sns.boxplot(data = df, x = 'sex', y = 's1')
# Out:
# <Axes: xlabel='sex', ylabel='s1'>

# %% [markdown]
# ### Bar Plot

# %% [markdown]
# * Bar graphs are used to compare things between different groups or to track changes over time.
# * when trying to measure change over time, bar graphs are best when the changes are larger.

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.barplot(data = df1, x = "BloodPressure", y = "DiabetesPedigreeFunction", hue = "Outcome")
# Out:
# <Axes: xlabel='BloodPressure', ylabel='DiabetesPedigreeFunction'>

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data = df1, x = "BMI", kde  = True)
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %% [markdown]
# * The BMI of the people is almost normal (symmetrical).
